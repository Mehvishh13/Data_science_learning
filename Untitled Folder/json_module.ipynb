# %%
# javascript object notation is a lightweight data format used for data exchange between servers and applications.
# It is widely used in APIs , web applications and configuartion
# python provides json module to work with json data

# %%
import json
obj={"name":"Mehez","age":25,"profession":"Engineer"}

# %%
s=json.dumps(obj)
type(s)
print(s)
# Out:
# {"name": "Mehez", "age": 25, "profession": "Engineer"}

# %%
d=json.loads('{"name": "Mehez", "age": 25, "profession": "Engineer"}')

# %%
type(d)
# Out:
# dict

# %%
file=open("data.json","w")

# %%
json.dump(obj,file)
