# %%
#set-> unordered , mutable and unique collection of elements 

empty_set=set()

numbers={1,2,3,4}

# %%
unique_ele=set([1,3,4,2,3,5]) #typecasting a list into set

# %%
print(unique_ele)
# Out:
# {1, 2, 3, 4, 5}

# %%
numbers.remove(3)

# %%
print(numbers)
# Out:
# {1, 2, 4}

# %%
num2={6,7,8,9,4}
numbers.union(num2)
# Out:
# {1, 2, 4, 6, 7, 8, 9}
