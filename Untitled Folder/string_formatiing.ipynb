# %%
#string is immutable-> it does not suppot item assignment
# string method returns you a new string, it doesnot change the existing string

# %%
#using format() in string 
name="Mehvxd"
age=23
print("My name is {} and {} years old".format(name, age))
# Out:
# My name is Mehvxd and 23 years old

# %%
print(f"My name is {name} and I am {age}")
# Out:
# My name is Mehvxd and I am 23
