# %%
d={}  #empty dictionary
type(d)
# Out:
# dict

# %%
student={
    "name":"Alice",
    "age":25,
    "grade":'A'
}

# %%
person=dict(name="John", age=30, city="New York")

# %%
student["name"]
# Out:
# 'Alice'

# %%
r=student.get("grade")

# %% [raw]
# print(r)
