# %%
#tuple -> immutable means can not be modified
tup=(1,2,388,3,23,4,80,50)
print(tup)
# Out:
# (1, 2, 388, 3, 23, 4, 80, 50)

# %%
len(tup)
# Out:
# 8

# %%
tup[3]
# Out:
# 3

# %%
#packing 
person=("ram", 30, "engineer")

#unpacking 
name,age, profession=person
name
# Out:
# 'ram'

# %%
profession
# Out:
# 'engineer'

# %%
#single tuple
single_ele=(42,)
