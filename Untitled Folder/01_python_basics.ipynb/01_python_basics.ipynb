# %%
a=5
b=34

# %%
str="Henry"

# %%
print("Hello world ")
# Out:
# Hello world

# %%
#this is a comment

# %%
convert=int(5.56)

# %%
print(convert)
# Out:
# 5

# %%
name="Mio"
print(name)
# Out:
# Mio

# %%
alpha='A'
cast2=float(6)
print(cast2)
# Out:
# 6.0

# %%
#String
name="Mehvish"

# %%
name.upper()
# Out:
# 'MEHVISH'

# %%
name.endswith("jerry")
# Out:
# False

# %%
name.count('e')
# Out:
# 1

# %%
len(name)
# Out:
# 7

# %%
name[0:5]
# Out:
# 'Mehvi'

# %%
name[-1:4]
# Out:
# ''

# %%
name[1:-1]
# Out:
# 'ehvis'

# %%
name[1:6]
# Out:
# 'ehvis'

# %%
name[::-1]
# Out:
# 'hsivheM'

# %%
name[::-2]
# Out:
# 'hihM'

# %%
name[::2]
# Out:
# 'Mhih'

# %%
#Taking input from the user
a=input("Enter the value of a")
#be default it takes user input as string
# Out:
# Enter the value of a 43

# %%
b=input("Enter the value of b")
# Out:
# Enter the value of b 32

# %%
a+b
# Out:
# '4332'

# %%
int(a)+int(b)
# Out:
# 75
