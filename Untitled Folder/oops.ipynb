# %%
#class-> blueprint for creating objects
#object-> instance of a class with specific data and behaviour
#attributes-> variables that store data for an object
#encapsulation-> restricting direct access to an object data
#inheritance-> creating a new class from an existing class
#polymorphism-> using the same method name for different classes

# %%
class Car:
    def __init__(self, brand, model):
        self.brand = brand  # Attribute
        self.model = model  # Attribute

    def display_info(self):  # Method
        return f"{self.brand} {self.model}"

# Creating an Object (Instance)
car1 = Car("Toyota", "Camry")
print(car1.display_info())  # Output: Toyota Camry
# Out:
# Toyota Camry

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # Private Attribute

    def get_balance(self):  # Getter
        return self.__balance

    def deposit(self, amount):  # Setter
        if amount > 0:
            self.__balance += amount

# Using Encapsulation
account = BankAccount(1000)
account.deposit(500)
print(account.get_balance())  # Output: 1500
# Out:
# 1500

# %%
@staticmethod  #can be called without self
def printTime():
    print(f"The time is now")
