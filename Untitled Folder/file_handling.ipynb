# %%
#read, write and manipulate the files stored in the disk

# %%
file= open("text.txt","r")

# %%
f.read()
# Out:
# 'mehvish is a software engineer'

# %% [raw]
# s="This is  a nice way to learn data science"

# %%
file.close()

# %%
f=open("harry.txt","w")

# %%
f.write(s)
# Out:
# 30

# %%
f.close()

# %%
# use of with statement
with open("harry.txt","r") as file:
    content=file.read() #read all content at a time
    print(content)
# Out:
# hi hi nbsvdfyuewgtyd
# bfregfuygr
# bdysugxzys

# %%
file=open("text.txt","r")
content2=file.readline() # one line
content3=file.readlines()  # read all lines into a list
file.close()

# %%
import os

if os.path.exists("example.txt"):
    print("File exist!")
else:
    print("File not found")
# Out:
# File not found

# %%
import os

if os.path.exists("example.txt"):
    os.remove("example.txt")
    print("File deleted.")
else:
    print("File does not exist.")
# Out:
# File does not exist.
