# %%
# Selecting rows and columns
import pandas as pd
df=pd.read_excel("data.xlsx")

# %%
df
# Out:
#       Name School  Marks
# 0  Shubham    SPS     56
# 1   Joshua   UPES     77
# 2     Jack    LPU     45
# 3     Alex    RIT     67
# 4    Rishi    NIT     78
# 5    Akash    RTS     90

# %%
df["Name"][0]
# Out:
# 'Shubham'

# %%
df.loc[3]   # row at index 3
# Out:
# Name      Alex
# School     RIT
# Marks       67
# Name: 3, dtype: object

# %%
df.iloc[3]
# Out:
# Name      Alex
# School     RIT
# Marks       67
# Name: 3, dtype: object

# %%
df.loc[0, "Name"]        # Value at row 0, column 'Name'
# Out:
# 'Shubham'

# %%
df.iloc[0, 1]            # Value at row 0, column at index 1
# Out:
# 'SPS'

# %%
df.loc[0:2, ["Name", "Marks"]]   # Rows 0 to 2, selected columns
# Out:
#       Name  Marks
# 0  Shubham     56
# 1   Joshua     77
# 2     Jack     45

# %%
df.iloc[0:2, 0:2]
# Out:
#       Name School
# 0  Shubham    SPS
# 1   Joshua   UPES

# %%
df.at[0, "Name"]       # Fast label-based access
df.iat[0, 1]           # Fast position-based access
# Out:
# 'SPS'

# %%
df[df["Marks"] > 60]
# Out:
#      Name School  Marks
# 1  Joshua   UPES     77
# 3    Alex    RIT     67
# 4   Rishi    NIT     78
# 5   Akash    RTS     90

# %%
df[(df["Marks"] > 25) & (df["School"] == "UPES")]
# Out:
#      Name School  Marks
# 1  Joshua   UPES     77

# %%
df[(df["Name"] == "Joshua") | (df["Marks"] < 60)]
# Out:
#       Name School  Marks
# 0  Shubham    SPS     56
# 1   Joshua   UPES     77
# 2     Jack    LPU     45

# %%
#The .query() method in pandas lets you filter DataFrame rows using a string expression — it's a more readable and often more concise alternative to using boolean indexing.

# %%
df.query("Marks > 85 and Name == 'Akash'")
# Out:
#     Name School  Marks
# 5  Akash    RTS     90
